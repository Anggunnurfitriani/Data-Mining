# %% [markdown]
# # Tugas 2

# %%
import pandas as pd
import numpy as np

# %%
temp= pd.read_csv("temperature.csv")

# %%
temp
# Out:
#                   datetime   Vancouver    Portland  San Francisco     Seattle  \
# 0      2012-10-01 13:00:00  284.630000  282.080000     289.480000  281.800000
# 1      2012-10-01 14:00:00  284.629041  282.083252     289.474993  281.797217
# 2      2012-10-01 15:00:00  284.626998  282.091866     289.460618  281.789833
# 3      2012-10-01 16:00:00  284.624955  282.100481     289.446243  281.782449
# 4      2012-10-01 17:00:00  284.622911  282.109095     289.431869  281.775065
# 5      2012-10-01 18:00:00  284.620868  282.117710     289.417494  281.767681
# 6      2012-10-01 19:00:00  284.618824  282.126324     289.403119  281.760297
# 7      2012-10-01 20:00:00  284.616781  282.134939     289.388745  281.752912
# 8      2012-10-01 21:00:00  284.614738  282.143553     289.374370  281.745528
# 9      2012-10-01 22:00:00  284.612694  282.152168     289.359995  281.738144
# 10     2012-10-01 23:00:00  284.610651  282.160782     289.345621  281.730760
# ...

# %%
np.sum(temp.isnull())
# Out:
# datetime               0
# Vancouver            794
# Portland               0
# San Francisco        792
# Seattle                2
# Los Angeles            2
# San Diego              0
# Las Vegas              0
# Phoenix                2
# Albuquerque            0
# Denver                 0
# San Antonio            0
# Dallas                 3
# Houston                2
# Kansas City            0
# Minneapolis           12
# Saint Louis            0
# Chicago                2
# Nashville              1
# Indianapolis           6
# Atlanta                5
# Detroit                0
# Jacksonville           0
# Charlotte              2
# Miami                804
# Pittsburgh             2
# Toronto                0
# Philadelphia           2
# New York             792
# Montreal               2
# Boston                 2
# Beersheba            797
# Tel Aviv District    792
# Eilat                792
# Haifa                797
# Nahariyya            796
# Jerusalem            792
# ...

# %%
temp['Vancouver']=temp['Vancouver'].fillna((temp['Vancouver'].mean()))
temp['San Francisco']=temp['San Francisco'].fillna((temp['San Francisco'].mean()))
temp['Seattle']=temp['Seattle'].fillna((temp['Seattle'].mean()))
temp['Los Angeles']=temp['Los Angeles'].fillna((temp['Los Angeles'].mean()))
temp['Phoenix']=temp['Phoenix'].fillna((temp['Phoenix'].mean()))
temp['Dallas']=temp['Dallas'].fillna((temp['Dallas'].mean()))
temp['Houston']=temp['Houston'].fillna((temp['Houston'].mean()))
temp['Minneapolis']=temp['Minneapolis'].fillna((temp['Minneapolis'].mean()))
temp['Chicago']=temp['Chicago'].fillna((temp['Chicago'].mean()))
temp['Nashville']=temp['Nashville'].fillna((temp['Nashville'].mean()))
temp['Indianapolis']=temp['Indianapolis'].fillna((temp['Indianapolis'].mean()))
temp['Atlanta']=temp['Atlanta'].fillna((temp['Atlanta'].mean()))
temp['Charlotte']=temp['Charlotte'].fillna((temp['Charlotte'].mean()))
temp['Miami']=temp['Miami'].fillna((temp['Miami'].mean()))
temp['Pittsburgh']=temp['Pittsburgh'].fillna((temp['Pittsburgh'].mean()))
temp['Philadelphia']=temp['Philadelphia'].fillna((temp['Philadelphia'].mean()))
temp['New York']=temp['New York'].fillna((temp['New York'].mean()))
temp['Montreal']=temp['Montreal'].fillna((temp['Montreal'].mean()))
temp['Boston']=temp['Boston'].fillna((temp['Boston'].mean()))
temp['Beersheba']=temp['Beersheba'].fillna((temp['Beersheba'].mean()))
temp['Tel Aviv District']=temp['Tel Aviv District'].fillna((temp['Tel Aviv District'].mean()))
temp['Eilat']=temp['Eilat'].fillna((temp['Eilat'].mean()))
temp['Haifa']=temp['Haifa'].fillna((temp['Haifa'].mean()))
temp['Nahariyya']=temp['Nahariyya'].fillna((temp['Nahariyya'].mean()))
temp['Jerusalem']=temp['Jerusalem'].fillna((temp['Jerusalem'].mean()))
np.sum(temp.isnull())
# Out:
# datetime             0
# Vancouver            0
# Portland             0
# San Francisco        0
# Seattle              0
# Los Angeles          0
# San Diego            0
# Las Vegas            0
# Phoenix              0
# Albuquerque          0
# Denver               0
# San Antonio          0
# Dallas               0
# Houston              0
# Kansas City          0
# Minneapolis          0
# Saint Louis          0
# Chicago              0
# Nashville            0
# Indianapolis         0
# Atlanta              0
# Detroit              0
# Jacksonville         0
# Charlotte            0
# Miami                0
# Pittsburgh           0
# Toronto              0
# Philadelphia         0
# New York             0
# Montreal             0
# Boston               0
# Beersheba            0
# Tel Aviv District    0
# Eilat                0
# Haifa                0
# Nahariyya            0
# Jerusalem            0
# dtype: int64

# %%
# outlier inspection
from scipy import stats

# %%
z= np.abs(stats.zscore(temp._get_numeric_data()))
print (z)
temp2= temp[(z<3).all(axis=1)]
# untuk mengetahui ukuran akhir data setelah menghilangkan outlier
print(temp2.shape)
# Out:
# [[1.16590609e-01 3.90873602e-01 2.50510264e-01 ... 1.45705120e+00
#   1.64926531e+00 1.46714852e+00]
#  [1.16444945e-01 3.90437233e-01 2.49562997e-01 ... 1.45705120e+00
#   1.64926531e+00 1.46714852e+00]
#  [1.16134473e-01 3.89281290e-01 2.46843569e-01 ... 1.45705120e+00
#   1.64926531e+00 1.46714852e+00]
#  ...
#  [1.03641485e-12 2.15090263e-01 2.97878142e-12 ... 6.96424677e-12
#   8.72434918e-12 2.12622564e-12]
#  [1.03641485e-12 2.64738993e-01 2.97878142e-12 ... 6.96424677e-12
#   8.72434918e-12 2.12622564e-12]
#  [1.03641485e-12 3.64036451e-01 2.97878142e-12 ... 6.96424677e-12
#   8.72434918e-12 2.12622564e-12]]
# (43588, 37)

# %%
temp2
# Out:
#                   datetime   Vancouver    Portland  San Francisco     Seattle  \
# 0      2012-10-01 13:00:00  284.630000  282.080000     289.480000  281.800000
# 1      2012-10-01 14:00:00  284.629041  282.083252     289.474993  281.797217
# 2      2012-10-01 15:00:00  284.626998  282.091866     289.460618  281.789833
# 3      2012-10-01 16:00:00  284.624955  282.100481     289.446243  281.782449
# 4      2012-10-01 17:00:00  284.622911  282.109095     289.431869  281.775065
# 5      2012-10-01 18:00:00  284.620868  282.117710     289.417494  281.767681
# 6      2012-10-01 19:00:00  284.618824  282.126324     289.403119  281.760297
# 7      2012-10-01 20:00:00  284.616781  282.134939     289.388745  281.752912
# 8      2012-10-01 21:00:00  284.614738  282.143553     289.374370  281.745528
# 9      2012-10-01 22:00:00  284.612694  282.152168     289.359995  281.738144
# 10     2012-10-01 23:00:00  284.610651  282.160782     289.345621  281.730760
# ...
