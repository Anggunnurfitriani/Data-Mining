# %% [markdown]
# # ETS DATMIN

# %%
import pandas as pd
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules
import numpy as np

# %%
data= pd.read_csv('online_retail.csv')
data.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#      InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/10 08:26       2.55     17850.0  United Kingdom
# 1  12/1/10 08:26       3.39     17850.0  United Kingdom
# 2  12/1/10 08:26       2.75     17850.0  United Kingdom
# 3  12/1/10 08:26       3.39     17850.0  United Kingdom
# 4  12/1/10 08:26       3.39     17850.0  United Kingdom

# %%
data.shape
# Out:
# (541909, 8)

# %%
np.sum(data.isnull())
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %%
# data memiliki beberapa komponen kosong yang harus dibersihkan
data['Description'] = data['Description'].str.strip()
data.dropna(axis=0, subset=['InvoiceNo'], inplace=True)

# %%
data['InvoiceNo'] = data['InvoiceNo'].astype('str')
data = data[~data['InvoiceNo'].str.contains('C')]

# %%
data.head
# Out:
# <bound method NDFrame.head of        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# 5         536365     22752         SET 7 BABUSHKA NESTING BOXES         2
# 6         536365     21730    GLASS STAR FROSTED T-LIGHT HOLDER         6
# 7         536366     22633               HAND WARMER UNION JACK         6
# 8         536366     22632            HAND WARMER RED POLKA DOT         6
# 9         536367     84879        ASSORTED COLOUR BIRD ORNAMENT        32
# 10        536367     22745            POPPY'S PLAYHOUSE BEDROOM         6
# ...

# %%
#pemisahan dengan tempat berdasarkan negara
tempat1 = (data[data['Country'] =="France"].groupby(['InvoiceNo', 'Description'])['Quantity'].sum().unstack().reset_index().fillna(0).set_index('InvoiceNo'))

# %%
tempat1.head()
# Out:
# Description  10 COLOUR SPACEBOY PEN  12 COLOURED PARTY BALLOONS  \
# InvoiceNo
# 536370                          0.0                         0.0
# 536852                          0.0                         0.0
# 536974                          0.0                         0.0
# 537065                          0.0                         0.0
# 537463                          0.0                         0.0
#
# Description  12 EGG HOUSE PAINTED WOOD  12 MESSAGE CARDS WITH ENVELOPES  \
# InvoiceNo
# 536370                             0.0                              0.0
# 536852                             0.0                              0.0
# 536974                             0.0                              0.0
# 537065                             0.0                              0.0
# 537463                             0.0                              0.0
#
# Description  12 PENCIL SMALL TUBE WOODLAND  \
# InvoiceNo
# 536370                                 0.0
# ...

# %%
#untuk menghilangkan transaksi dengan keterangan postage
def encode_units(x):
    if x <= 0:
        return 0
    if x >= 1:
        return 1

tempat1_sets = tempat1.applymap(encode_units)
tempat1_sets.drop('POSTAGE', inplace=True, axis=1)

# %%
#frequents item set
fi = apriori(tempat1_sets, min_support=0.05, use_colnames=True)
fi
# Out:
#       support                                           itemsets
# 0    0.071429                      (4 TRADITIONAL SPINNING TOPS)
# 1    0.096939                       (ALARM CLOCK BAKELIKE GREEN)
# 2    0.102041                        (ALARM CLOCK BAKELIKE PINK)
# 3    0.094388                         (ALARM CLOCK BAKELIKE RED)
# 4    0.068878                       (ASSORTED COLOUR MINI CASES)
# 5    0.081633                     (BAKING SET 9 PIECE RETROSPOT)
# 6    0.051020                            (BLUE HARMONICA IN BOX)
# 7    0.068878                      (CHARLOTTE BAG APPLES DESIGN)
# 8    0.066327                  (CHARLOTTE BAG DOLLY GIRL DESIGN)
# 9    0.058673                      (CHARLOTTE BAG PINK POLKADOT)
# 10   0.051020                      (CHILDREN'S APRON DOLLY GIRL)
# 11   0.066327                  (CHILDRENS APRON SPACEBOY DESIGN)
# 12   0.071429                     (CHILDRENS CUTLERY DOLLY GIRL)
# ...

# %%
associationrules = association_rules(fi, metric="lift", min_threshold=0.8)

# %%
associationrules
# Out:
#                                           antecedents  \
# 0                         (ALARM CLOCK BAKELIKE PINK)
# 1                        (ALARM CLOCK BAKELIKE GREEN)
# 2                          (ALARM CLOCK BAKELIKE RED)
# 3                        (ALARM CLOCK BAKELIKE GREEN)
# 4                         (ALARM CLOCK BAKELIKE PINK)
# 5                          (ALARM CLOCK BAKELIKE RED)
# 6                          (ALARM CLOCK BAKELIKE RED)
# 7                (ROUND SNACK BOXES SET OF4 WOODLAND)
# 8                      (CHILDRENS CUTLERY DOLLY GIRL)
# 9                        (CHILDRENS CUTLERY SPACEBOY)
# 10                               (SPACEBOY LUNCH BOX)
# 11                             (DOLLY GIRL LUNCH BOX)
# 12                          (LUNCH BAG RED RETROSPOT)
# 13                           (LUNCH BAG APPLE DESIGN)
# 14                        (LUNCH BAG SPACEBOY DESIGN)
# 15                           (LUNCH BAG APPLE DESIGN)
# ...

# %%
associationrules[ (associationrules['lift'] >= 3) & (associationrules['confidence'] >= 0.2) ]
# Out:
#                                           antecedents  \
# 0                         (ALARM CLOCK BAKELIKE PINK)
# 1                        (ALARM CLOCK BAKELIKE GREEN)
# 2                          (ALARM CLOCK BAKELIKE RED)
# 3                        (ALARM CLOCK BAKELIKE GREEN)
# 4                         (ALARM CLOCK BAKELIKE PINK)
# 5                          (ALARM CLOCK BAKELIKE RED)
# 6                          (ALARM CLOCK BAKELIKE RED)
# 7                (ROUND SNACK BOXES SET OF4 WOODLAND)
# 8                      (CHILDRENS CUTLERY DOLLY GIRL)
# 9                        (CHILDRENS CUTLERY SPACEBOY)
# 10                               (SPACEBOY LUNCH BOX)
# 11                             (DOLLY GIRL LUNCH BOX)
# 12                          (LUNCH BAG RED RETROSPOT)
# 13                           (LUNCH BAG APPLE DESIGN)
# 14                        (LUNCH BAG SPACEBOY DESIGN)
# 15                           (LUNCH BAG APPLE DESIGN)
# ...

# %%
#diaplikasikan pada semua nedara dengan rules yang sama
tempat2 = (data[data['Country'] =="Germany"]
          .groupby(['InvoiceNo', 'Description'])['Quantity']
          .sum().unstack().reset_index().fillna(0)
          .set_index('InvoiceNo'))

# %%
tempat2.head()
# Out:
# Description  10 COLOUR SPACEBOY PEN  12 COLOURED PARTY BALLOONS  \
# InvoiceNo
# 536527                          0.0                         0.0
# 536840                          0.0                         0.0
# 536861                          0.0                         0.0
# 536967                          0.0                         0.0
# 536983                          0.0                         0.0
#
# Description  12 IVORY ROSE PEG PLACE SETTINGS  \
# InvoiceNo
# 536527                                    0.0
# 536840                                    0.0
# 536861                                    0.0
# 536967                                    0.0
# 536983                                    0.0
#
# Description  12 MESSAGE CARDS WITH ENVELOPES  12 PENCIL SMALL TUBE WOODLAND  \
# InvoiceNo
# 536527                                   0.0                            0.0
# 536840                                   0.0                            0.0
# ...

# %%
tempat2_sets = tempat2.applymap(encode_units)
tempat2_sets.drop('POSTAGE', inplace=True, axis=1)
fi2 = apriori(tempat2_sets, min_support=0.05, use_colnames=True)
associationrules2 = association_rules(fi2, metric="lift", min_threshold=0.08)

associationrules2[ (associationrules2['lift'] >= 3) &
        (associationrules2['confidence'] >= 0.2)]
# Out:
#                              antecedents  \
# 0        (PLASTERS IN TIN CIRCUS PARADE)
# 1     (PLASTERS IN TIN WOODLAND ANIMALS)
# 6     (PLASTERS IN TIN WOODLAND ANIMALS)
# 7             (PLASTERS IN TIN SPACEBOY)
# 10              (WOODLAND CHARLOTTE BAG)
# 11         (RED RETROSPOT CHARLOTTE BAG)
# 12  (ROUND SNACK BOXES SET OF4 WOODLAND)
# 13   (ROUND SNACK BOXES SET OF 4 FRUITS)
#
#                              consequents  antecedent support  \
# 0     (PLASTERS IN TIN WOODLAND ANIMALS)            0.115974
# 1        (PLASTERS IN TIN CIRCUS PARADE)            0.137856
# 6             (PLASTERS IN TIN SPACEBOY)            0.137856
# 7     (PLASTERS IN TIN WOODLAND ANIMALS)            0.107221
# 10         (RED RETROSPOT CHARLOTTE BAG)            0.126915
# 11              (WOODLAND CHARLOTTE BAG)            0.070022
# 12   (ROUND SNACK BOXES SET OF 4 FRUITS)            0.245077
# 13  (ROUND SNACK BOXES SET OF4 WOODLAND)            0.157549
#
# ...

# %%
data.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#      InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/10 08:26       2.55     17850.0  United Kingdom
# 1  12/1/10 08:26       3.39     17850.0  United Kingdom
# 2  12/1/10 08:26       2.75     17850.0  United Kingdom
# 3  12/1/10 08:26       3.39     17850.0  United Kingdom
# 4  12/1/10 08:26       3.39     17850.0  United Kingdom

# %%
tempat3 = (data[data['Country'] =="United Kingdom"].groupby(['InvoiceNo', 'Description'])['Quantity'].sum().unstack().reset_index().fillna(0).set_index('InvoiceNo'))

# %%
tempat3.head()
# Out:
# Description  *Boombox Ipod Classic  *USB Office Mirror Ball  \
# InvoiceNo
# 536365                         0.0                      0.0
# 536366                         0.0                      0.0
# 536367                         0.0                      0.0
# 536368                         0.0                      0.0
# 536369                         0.0                      0.0
#
# Description  10 COLOUR SPACEBOY PEN  12 COLOURED PARTY BALLOONS  \
# InvoiceNo
# 536365                          0.0                         0.0
# 536366                          0.0                         0.0
# 536367                          0.0                         0.0
# 536368                          0.0                         0.0
# 536369                          0.0                         0.0
#
# Description  12 DAISY PEGS IN WOOD BOX  12 EGG HOUSE PAINTED WOOD  \
# InvoiceNo
# 536365                             0.0                        0.0
# ...

# %%
def encode_units(x):
    if x <= 0:
        return 0
    if x >= 1:
        return 1

tempat3_sets = tempat3.applymap(encode_units)
tempat3_sets.drop('POSTAGE', inplace=True, axis=1)

# %%
fi3 = apriori(tempat3_sets, min_support=0.03, use_colnames=True)

# %%
fi3
# Out:
#       support                                           itemsets
# 0    0.045800                           (6 RIBBONS RUSTIC CHARM)
# 1    0.031123                  (60 CAKE CASES VINTAGE CHRISTMAS)
# 2    0.040336                      (60 TEATIME FAIRY CAKE CASES)
# 3    0.046925                       (ALARM CLOCK BAKELIKE GREEN)
# 4    0.035140                        (ALARM CLOCK BAKELIKE PINK)
# 5    0.049818                         (ALARM CLOCK BAKELIKE RED)
# 6    0.036212                     (ANTIQUE SILVER T-LIGHT GLASS)
# 7    0.073441                    (ASSORTED COLOUR BIRD ORNAMENT)
# 8    0.042265                     (BAKING SET 9 PIECE RETROSPOT)
# 9    0.035087                              (BATHROOM METAL SIGN)
# 10   0.036105                      (CHARLOTTE BAG PINK POLKADOT)
# 11   0.043068                        (CHARLOTTE BAG SUKI DESIGN)
# 12   0.034926                                    (CHILLI LIGHTS)
# ...

# %%
associationrules3 = association_rules(fi3, metric="lift", min_threshold=0.08)

# %%
associationrules3
# Out:
#                             antecedents                          consequents  \
# 0            (ALARM CLOCK BAKELIKE RED)         (ALARM CLOCK BAKELIKE GREEN)
# 1          (ALARM CLOCK BAKELIKE GREEN)           (ALARM CLOCK BAKELIKE RED)
# 2      (PINK REGENCY TEACUP AND SAUCER)    (GREEN REGENCY TEACUP AND SAUCER)
# 3     (GREEN REGENCY TEACUP AND SAUCER)     (PINK REGENCY TEACUP AND SAUCER)
# 4     (ROSES REGENCY TEACUP AND SAUCER)    (GREEN REGENCY TEACUP AND SAUCER)
# 5     (GREEN REGENCY TEACUP AND SAUCER)    (ROSES REGENCY TEACUP AND SAUCER)
# 6      (JUMBO  BAG BAROQUE BLACK WHITE)            (JUMBO BAG RED RETROSPOT)
# 7             (JUMBO BAG RED RETROSPOT)     (JUMBO  BAG BAROQUE BLACK WHITE)
# 8             (JUMBO BAG RED RETROSPOT)            (JUMBO BAG PINK POLKADOT)
# 9             (JUMBO BAG PINK POLKADOT)            (JUMBO BAG RED RETROSPOT)
# 10  (JUMBO SHOPPER VINTAGE RED PAISLEY)            (JUMBO BAG RED RETROSPOT)
# ...

# %%
associationrules3[ (associationrules3['lift'] >= 3) &
        (associationrules3['confidence'] >= 0.2)]
# Out:
#                             antecedents                          consequents  \
# 0            (ALARM CLOCK BAKELIKE RED)         (ALARM CLOCK BAKELIKE GREEN)
# 1          (ALARM CLOCK BAKELIKE GREEN)           (ALARM CLOCK BAKELIKE RED)
# 2      (PINK REGENCY TEACUP AND SAUCER)    (GREEN REGENCY TEACUP AND SAUCER)
# 3     (GREEN REGENCY TEACUP AND SAUCER)     (PINK REGENCY TEACUP AND SAUCER)
# 4     (ROSES REGENCY TEACUP AND SAUCER)    (GREEN REGENCY TEACUP AND SAUCER)
# 5     (GREEN REGENCY TEACUP AND SAUCER)    (ROSES REGENCY TEACUP AND SAUCER)
# 6      (JUMBO  BAG BAROQUE BLACK WHITE)            (JUMBO BAG RED RETROSPOT)
# 7             (JUMBO BAG RED RETROSPOT)     (JUMBO  BAG BAROQUE BLACK WHITE)
# 8             (JUMBO BAG RED RETROSPOT)            (JUMBO BAG PINK POLKADOT)
# 9             (JUMBO BAG PINK POLKADOT)            (JUMBO BAG RED RETROSPOT)
# 10  (JUMBO SHOPPER VINTAGE RED PAISLEY)            (JUMBO BAG RED RETROSPOT)
# ...
